# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set()

# %%
data=pd.read_csv("P1-OfficeSupplies.csv")

# %%
data.describe()
# Out:
#            Units  Unit Price
# count  43.000000   43.000000
# mean   49.325581   20.308605
# std    30.078248   47.345118
# min     2.000000    1.290000
# 25%    27.500000    3.990000
# 50%    53.000000    4.990000
# 75%    74.500000   17.990000
# max    96.000000  275.000000

# %%
data
# Out:
#       OrderDate   Region      Rep     Item  Units  Unit Price
# 0    4-Jul-2014     East  Richard  Pen Set     62        4.99
# 1   12-Jul-2014     East     Nick   Binder     29        1.99
# 2   21-Jul-2014  Central   Morgan  Pen Set     55       12.49
# 3   29-Jul-2014     East    Susan   Binder     81       19.99
# 4    7-Aug-2014  Central  Matthew  Pen Set     42       23.95
# 5   15-Aug-2014     East  Richard   Pencil     35        4.99
# 6   24-Aug-2014     West    James     Desk      3      275.00
# 7    1-Sep-2014  Central    Smith     Desk      2      125.00
# 8   10-Sep-2014  Central     Bill   Pencil      7        1.29
# 9   18-Sep-2014     East  Richard  Pen Set     16       15.99
# 10  27-Sep-2014     West    James      Pen     76        1.99
# 11   5-Oct-2014  Central   Morgan   Binder     28        8.99
# 12  14-Oct-2014     West   Thomas   Binder     57       19.99
# 13  22-Oct-2014     East  Richard      Pen     64        8.99
# ...

# %%
data.isnull().sum()
# Out:
# OrderDate     0
# Region        0
# Rep           0
# Item          0
# Units         0
# Unit Price    0
# dtype: int64

# %%
data.columns
# Out:
# Index(['OrderDate', 'Region', 'Rep', 'Item', 'Units', 'Unit Price'], dtype='object')

# %%
data["Total Values"]=data["Units"]*data["Unit Price"]

# %%
data["Total Values"]
# Out:
# 0      309.38
# 1       57.71
# 2      686.95
# 3     1619.19
# 4     1005.90
# 5      174.65
# 6      825.00
# 7      250.00
# 8        9.03
# 9      255.84
# 10     151.24
# 11     251.72
# 12    1139.43
# 13     575.36
# 14      18.06
# 15     299.85
# 16      54.89
# 17     479.04
# 18    1879.06
# 19      86.43
# 20     139.72
# 21    1183.26
# 22     189.05
# 23     413.54
# 24     999.50
# 25    1305.00
# 26     179.64
# 27      19.96
# 28     539.73
# 29     139.93
# 30     167.44
# 31     249.50
# 32     299.40
# 33     131.34
# 34     149.25
# 35     479.04
# 36     449.10
# 37      68.37
# 38      63.68
# 39     719.20
# 40     539.40
# 41     625.00
# 42     449.10
# Name: Total Values, dtype: float64

# %%
data.describe()
# Out:
#            Units  Unit Price  Total Values
# count  43.000000   43.000000     43.000000
# mean   49.325581   20.308605    456.462326
# std    30.078248   47.345118    447.022104
# min     2.000000    1.290000      9.030000
# 25%    27.500000    3.990000    144.590000
# 50%    53.000000    4.990000    299.400000
# 75%    74.500000   17.990000    600.180000
# max    96.000000  275.000000   1879.060000

# %%
sns.displot(data["Units"])

# %%
plt.figure(figsize=(20,10))
sns.displot(data["Unit Price"])

# %%
sns.displot(data["Total Values"])

# %%
data.to_csv("TotalValues.csv")
